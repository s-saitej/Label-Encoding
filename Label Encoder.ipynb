# %%
import pandas as pd

# %%
data = pd.read_excel('Iris.xls')

# %%
data
# Out:
#      sepal length  sepal width  petal length  petal width            iris
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# 5             5.4          3.9           1.7          0.4     Iris-setosa
# 6             4.6          3.4           1.4          0.3     Iris-setosa
# 7             5.0          3.4           1.5          0.2     Iris-setosa
# 8             4.4          2.9           1.4          0.2     Iris-setosa
# 9             4.9          3.1           1.5          0.1     Iris-setosa
# 10            5.4          3.7           1.5          0.2     Iris-setosa
# 11            4.8          3.4           1.6          0.2     Iris-setosa
# ...

# %%
from sklearn.preprocessing import LabelEncoder

# %%
encode = LabelEncoder()

# %%
data.columns
# Out:
# Index(['sepal length', 'sepal width', 'petal length', 'petal width', 'iris'], dtype='object')

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width         iris
# 0           5.1          3.5           1.4          0.2  Iris-setosa
# 1           4.9          3.0           1.4          0.2  Iris-setosa
# 2           4.7          3.2           1.3          0.2  Iris-setosa
# 3           4.6          3.1           1.5          0.2  Iris-setosa
# 4           5.0          3.6           1.4          0.2  Iris-setosa

# %%
data['iris'] = encode.fit_transform(data['iris'])

# %%
data.head()
# Out:
#    sepal length  sepal width  petal length  petal width  iris
# 0           5.1          3.5           1.4          0.2     0
# 1           4.9          3.0           1.4          0.2     0
# 2           4.7          3.2           1.3          0.2     0
# 3           4.6          3.1           1.5          0.2     0
# 4           5.0          3.6           1.4          0.2     0

# %%
data.tail()
# Out:
#      sepal length  sepal width  petal length  petal width  iris
# 145           6.7          3.0           5.2          2.3     2
# 146           6.3          2.5           5.0          1.9     2
# 147           6.5          3.0           5.2          2.0     2
# 148           6.2          3.4           5.4          2.3     2
# 149           5.9          3.0           5.1          1.8     2

# %%
data['iris'].unique()
# Out:
# array([0, 1, 2], dtype=int64)

# %%
from sklearn import svm

# %%
model = svm.SVC(kernel = 'linear', C = 1e3, gamma = 100)

# %%
from sklearn.model_selection import train_test_split

# %%
train_data, test_data, train_target, test_target = train_test_split(X,Y, test_size = 0.05)

# %%
X = data.iloc[:,:-1]
Y = data.iloc[:,-1:]

# %%
model.fit(train_data, train_target)
# Out:
# D:\Installers\Anaconda 3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVC(C=1000.0, cache_size=200, class_weight=None, coef0=0.0,
#   decision_function_shape='ovr', degree=3, gamma=100, kernel='linear',
#   max_iter=-1, probability=False, random_state=None, shrinking=True,
#   tol=0.001, verbose=False)

# %%
result = model.predict(test_data)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy = accuracy_score(result,test_target)

# %%
accuracy
# Out:
# 1.0

# %%
from matplotlib import pyplot as plt

# %%
# %matplotlib inline

# %%
plt.scatter(data.iloc[:50,0:1], data.iloc[:50,2:3], marker = 'x', color = 'red', label = "Setosa")
plt.scatter(data.iloc[50:100, 0:1], data.iloc[:50, 2:3], marker = 'o', color = 'yellow', label = "Versicolor")
plt.scatter(data.iloc[100:150, 0:1], data.iloc[100:150, 2:3], marker = '*', color = 'black', label = "Verginica")
plt.show()
